# %% [markdown]
# # Перемешиваем модальности

# %% [markdown]
# # Metadata
# transforms, model+optimizer+loss, hyperparams

# %%
TITLE = "int+flip, contextnet+adan+dicefocal"

# %% [markdown]
# # Imports

# %%
from glio.imports import *
from glio.importsglio import *

from glio.datasets.mri_preloaded import *
from glio.specific.mri_around import *
from glio.specific.vkr import *
from glio.transforms.intensity import RandScale, RandShift
from glio.transforms.spatial import RandFlipt

from glio.torch_tools import ConcatZeroChannelsToDataloader, BatchInputTransforms
# Out:
# d:\miniconda3\envs\pytorch311\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# # Dataset

# %%
bratstrain = get_ds_around(BRATS2024_NOHIST96_TRAIN) + get_ds_around(BRATS2024_NOHIST96_TEST)
rhuhtest = get_ds_around(RHUH_NOHIST140_NOADC_TRAIN) + get_ds_around(RHUH_NOHIST140_NOADC_TEST)

# %%
from monai import transforms as mtf

# fast tfms
gaussianblur = mtf.RandGaussianSmooth(prob=0.1) # type:ignore
contrast = mtf.RandAdjustContrast(gamma = (0.5, 2), prob=0.1) # type:ignore

# slower tfms
biasfield = mtf.RandBiasField(prob=0.1) # type:ignore
hist_shift = mtf.RandHistogramShift(prob=0.05) # type:ignore
gibbs = mtf.RandGibbsNoise(prob=0.1) # type:ignore
riccan = mtf.RandRicianNoise(std=0.5, prob=0.05) # type:ignore

# very slow
kspike = mtf.RandKSpaceSpikeNoise(prob=0.1) # type:ignore

def rand_shuffle_channels_around(x:torch.Tensor, channels_per = 3):
    if random.random() < 0.1:
        num_groups = int(x.shape[0] / channels_per)
        perm = torch.randperm(num_groups, dtype=torch.int32)
        img= x.reshape(num_groups, channels_per, *x.shape[1:])[perm].flatten(0, 1)
        return img
    return x

def rand_group_dropout(x):
    if random.random() < 0.1: return torch.zeros_like(x)
    if random.random() < 0.01: return torch.randn_like(x)
    return x

def randnoise(x):
    if random.random() < 0.1: return x + torch.randn_like(x) * random.triangular(0, 0.5, 0)
    return x

# %%
dstrain = DSToTarget(0)
dstest = DSToTarget(0)

dstrain.add_samples(bratstrain, loader_around_seq_fix, RandFlipt(p=0.5), get0, get1)
dstest.add_samples(rhuhtest, loader_around_seq, randcrop, get0, get1)
print(len(dstrain))
print(len(dstest))
# Out:
# 332625
# 20893

# %% [markdown]
# # Performance

# %%
x = torch.randn((3,96,96))
with perf_counter_context():
    for i in range(100):
        dstrain[i]
# Out:
# Context took 0.3880969000165351 perf_counter seconds

# %% [markdown]
# # Inputs / targets preview

# %%
fig = Figure()
sample_ = dstrain[300]
fig.add().imshow_batch(sample_[0]).style_img('inputs')
fig.add().imshow_batch(sample_[1]).style_img('targets')
sample_ = dstest[20]
fig.add().imshow_batch(sample_[0]).style_img('inputs - test')
fig.add().imshow_batch(sample_[1]).style_img('targets - test')
fig.create(2, figsize=(24,24))
# Out:
# (<Figure size 2400x2400 with 4 Axes>,
#  array([[<Axes: title={'center': 'inputs'}>,
#          <Axes: title={'center': 'targets'}>],
#         [<Axes: title={'center': 'inputs - test'}>,
#          <Axes: title={'center': 'targets - test'}>]], dtype=object))

# %% [markdown]
# # Model

# %%
from monai.networks.nets import HighResNet # type:ignore
def HighResNet_noReLUattheend(in_channels=12, out_channels=20):
    model = HighResNet(2, in_channels, out_channels)
    model.blocks[-1].adn = nn.Identity()
    return model

single_tfms = Compose(rand_shuffle_channels_around, GroupwiseTfms((randnoise, RandScale(p=0.3, val=(0.75, 1.5)), RandShift(p=0.3, val=(-0.3, 0.3)), rand_group_dropout)))
batch_tfms = torch.vmap(single_tfms, randomness='different')

mse = torch.nn.MSELoss()

class ContextHRN(nn.Module):
    def __init__(self):
        super().__init__()
        self.batch_tfms = batch_tfms
        self.hrn = HighResNet_noReLUattheend(12, 20)

    def forward(self, x:torch.Tensor):
        self.tfmed = self.batch_tfms(x)
        self.processed = self.hrn(self.tfmed)
        loss = mse(self.processed[:, :12], x)
        return self.processed[:,12:16], loss


summary(ContextHRN(), (4, 12, 96, 96))
# Out:
# path                                         module                                       input size               output size              params    buffers
# __main__.ContextHRN/hrn/blocks/0/conv        torch.nn.modules.conv.Conv2d                 (4, 12, 96, 96)          (4, 16, 96, 96)          1728      0
# __main__.ContextHRN/hrn/blocks/0/adn/N       torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/0/adn/A       torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/1/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/1/layers/0/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/1/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/1/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/1/layers/2/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/1/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/1/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/2/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/2/layers/0/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/2/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/2/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/2/layers/2/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/2/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/2/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/3/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/3/layers/0/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/3/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/3/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/3/layers/2/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/3/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextHRN/hrn/blocks/3/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/4/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextHRN/hrn/blocks/4/layers/0/A  torch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/4/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 32, 96, 96)          4608      0
# __main__.ContextHRN/hrn/blocks/4/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/4/layers/2/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/4/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextHRN/hrn/blocks/4/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/5/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/5/layers/0/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/5/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextHRN/hrn/blocks/5/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/5/layers/2/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/5/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextHRN/hrn/blocks/5/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/6/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/6/layers/0/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/6/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextHRN/hrn/blocks/6/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/6/layers/2/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/6/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextHRN/hrn/blocks/6/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/7/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextHRN/hrn/blocks/7/layers/0/A  torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/7/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 64, 96, 96)          18432     0
# __main__.ContextHRN/hrn/blocks/7/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextHRN/hrn/blocks/7/layers/2/A  torch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/7/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextHRN/hrn/blocks/7/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/8/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextHRN/hrn/blocks/8/layers/0/A  torch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/8/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextHRN/hrn/blocks/8/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextHRN/hrn/blocks/8/layers/2/A  torch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/8/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextHRN/hrn/blocks/8/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/9/layers/0/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextHRN/hrn/blocks/9/layers/0/A  torch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/9/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextHRN/hrn/blocks/9/layers/2/N  torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextHRN/hrn/blocks/9/layers/2/A  torch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/9/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextHRN/hrn/blocks/9/chn_pad     monai.networks.layers.simplelayers.ChannelPad(4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/10/conv       torch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 80, 96, 96)          5120      0
# __main__.ContextHRN/hrn/blocks/10/adn/N      torch.nn.modules.batchnorm.BatchNorm2d       (4, 80, 96, 96)          (4, 80, 96, 96)          160       161
# __main__.ContextHRN/hrn/blocks/10/adn/A      torch.nn.modules.activation.ReLU             (4, 80, 96, 96)          (4, 80, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/10/adn/D      torch.nn.modules.dropout.Dropout             (4, 80, 96, 96)          (4, 80, 96, 96)          0         0
# __main__.ContextHRN/hrn/blocks/11/conv       torch.nn.modules.conv.Conv2d                 (4, 80, 96, 96)          (4, 20, 96, 96)          1600      0
# __main__.ContextHRN/hrn/blocks/11/adn        torch.nn.modules.linear.Identity             (4, 20, 96, 96)          (4, 20, 96, 96)          0         0

# %% [markdown]
# # Train

# %%
from stuff.found.torch.optim.Adan import Adan
from monai.losses import DiceFocalLoss # type:ignore

MODEL = ContextHRN()
NAME = f"{MODEL.__class__.__name__}"
LR = 1e-1
BATCH_SIZE = 32
N_EPOCHS = 2

# dl_train = DataLoader(ds_train, BATCH_SIZE)
dltrain = DataLoader(dstrain, BATCH_SIZE, shuffle=True)
dltest = DataLoader(dstest, BATCH_SIZE)

OPT = Adan(MODEL.parameters(), lr=LR)
LOSS_FN = DiceFocalLoss(softmax=True)
SCHED = lr_scheduler.OneCycleLR(OPT, max_lr=LR, steps_per_epoch=len(dltrain), epochs=N_EPOCHS)
#SCHED = None

clean_mem()
# MODEL = gnn.LSUV(MODEL, dltrain, max_iter=10)

CALLBACKS =  (Metric_Loss(),
              Log_Time(), Save_Best(), Save_Last(), 
              #Log_LR(), 
              PerformanceTweaks(True), Accelerate("no"),
              MONAI_IoU(4, True, True, step=32, name='iou'),
              Torcheval_AURPC(4, True, step=32),
              Torcheval_AUROC(4, True, step=32),
              MONAI_ConfusionMatrix(step=4), MONAI_ConfusionMatrixMetrics(),
              MONAI_ConfusionMatrix(step=4, include_bg = False, name="nobg confusion matrix"), MONAI_ConfusionMatrixMetrics(key = 'nobg confusion matrix', prefix='nobg '),
              FastProgressBar(step_batch=128, plot=True, metrics=('train loss', 'test loss', 'train dice loss', 'test dice loss',
                                                                  'test balanced accuracy', 'test nobg balanced accuracy',
                                                                  'test f1 score', 'test nobg f1 score'), maxv=1),
              Summary(),
              PlotSummary(path='summaries'),
              PrintLoss(),
              SaveReferenceVisualizationsAfterEachEpoch('reference preds'),
              Metric_PredsTargetsFn(LOSS_FN, name='dice loss'),
              #CallTrainAndEvalOnOptimizer(),
              AddLossReturnedByModelToLossInGetLoss(),
            )

LEARNER_NAME = f"{TITLE} lr{LR:.0e} OneCycleLR"
learner = Learner(MODEL, LEARNER_NAME,
                  cbs = CALLBACKS,
                  loss_fn=LOSS_FN,
                  optimizer=OPT,
                  scheduler=SCHED,)
learner.fit(N_EPOCHS, dltrain, dltest, test_first=True, test_on_interrupt=False)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 1:37:53&lt;1:37:53]
#     </div>
#
#
#
#     <div>
#       <progress value='6052' class='' max='10395' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       58.22% [6052/10395 53:04&lt;38:05]
#     </div>
# test loss = 6.7960
# Keyboard interrupt, stopping the training...
# test loss: min: 1.7741; max: 3.0304; last: 1.7741
# test iou: min: 0.4603; max: 0.5931; last: 0.4603
# test average precision: min: 0.2438; max: 0.2635; last: 0.2635
# test roc auc: min: 0.4685; max: 0.5443; last: 0.5443
# test sensitivity: min: 0.2717; max: 0.2717; last: 0.2717
# test specificity: min: 0.7327; max: 0.7327; last: 0.7327
# test precision: min: 0.2420; max: 0.2420; last: 0.2420
# test negative predictive value: min: 0.7432; max: 0.7432; last: 0.7432
# test miss rate: min: 0.7283; max: 0.7283; last: 0.7283
# test fall out: min: 0.2673; max: 0.2673; last: 0.2673
# test false discovery rate: min: 0.7580; max: 0.7580; last: 0.7580
# test false omission rate: min: 0.2568; max: 0.2568; last: 0.2568
# test prevalence threshold: min: 0.5240; max: 0.5240; last: 0.5240
# test threat score: min: 0.1931; max: 0.1931; last: 0.1931
# test accuracy: min: 0.8689; max: 0.8689; last: 0.8689
# test balanced accuracy: min: 0.5022; max: 0.5022; last: 0.5022
# test f1 score: min: 0.2281; max: 0.2281; last: 0.2281
# test matthews correlation coefficient: min: -0.0087; max: -0.0087; last: -0.0087
# test fowlkes mallows index: min: 0.2389; max: 0.2389; last: 0.2389
# test informedness: min: 0.0043; max: 0.0043; last: 0.0043
# test markedness: min: -0.0148; max: -0.0148; last: -0.0148
# test nobg sensitivity: min: 0.0964; max: 0.0964; last: 0.0964
# test nobg specificity: min: 0.9349; max: 0.9349; last: 0.9349
# test nobg precision: min: 0.0183; max: 0.0183; last: 0.0183
# test nobg negative predictive value: min: 0.9738; max: 0.9738; last: 0.9738
# test nobg miss rate: min: 0.9036; max: 0.9036; last: 0.9036
# test nobg fall out: min: 0.0651; max: 0.0651; last: 0.0651
# test nobg false discovery rate: min: 0.9817; max: 0.9817; last: 0.9817
# test nobg false omission rate: min: 0.0262; max: 0.0262; last: 0.0262
# test nobg prevalence threshold: min: 0.5281; max: 0.5281; last: 0.5281
# test nobg threat score: min: 0.0104; max: 0.0104; last: 0.0104
# test nobg accuracy: min: 0.9106; max: 0.9106; last: 0.9106
# test nobg balanced accuracy: min: 0.5156; max: 0.5156; last: 0.5156
# test nobg f1 score: min: 0.0204; max: 0.0204; last: 0.0204
# test nobg matthews correlation coefficient: min: 0.0058; max: 0.0058; last: 0.0058
# test nobg fowlkes mallows index: min: 0.0340; max: 0.0340; last: 0.0340
# test nobg informedness: min: 0.0313; max: 0.0313; last: 0.0313
# test nobg markedness: min: -0.0079; max: -0.0079; last: -0.0079
# test dice loss: min: 1.0382; max: 1.2324; last: 1.2324
# time: min: 218.7366; max: 9058.4114; last: 9058.4114
# train loss: min: 0.2790; max: 1.2881; last: 0.6378
# train dice loss: min: 0.2763; max: 1.0443; last: 0.6249
# train iou: min: 0.7158; max: 0.9660; last: 0.9477
# train average precision: min: 0.2976; max: 0.5298; last: 0.4076
# train roc auc: min: 0.6470; max: 0.8776; last: 0.7730

# %%
i=0
inputs = dstest[4699][0].unsqueeze(0)
qimshow_batch(inputs[i], scale_each=True, maxelems=100)
learner.inference(inputs)
qimshow_batch(learner.model.tfmed[i], scale_each=True, maxelems=100)
qimshow_batch(learner.model.processed[i], scale_each=True, maxelems=100)
qimshow(learner.model.processed[i][-3:].argmax(0))
