# %%
from glio.logger.compare import Comparison
folder = r"F:\Stuff\Programming\experiments\vkr\training\BRATS-small + RHUH as test ds, 32\checkpoints"
c = Comparison.from_checkpoint_folder(folder)

# %%
c.plot_best("test loss", figsize=(14,6))

# %%
c.plot_best("test accuracy", 10, "max", figsize=(14,6))
