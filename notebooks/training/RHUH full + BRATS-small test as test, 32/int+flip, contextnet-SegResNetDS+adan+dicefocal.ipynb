# %% [markdown]
# # Перемешиваем модальности

# %% [markdown]
# # Metadata
# transforms, model+optimizer+loss, hyperparams

# %%
TITLE = "int+flip, contextnet-SegResNetDS+adan+dicefocal"

# %% [markdown]
# # Imports

# %%
from glio.imports import *
from glio.importsglio import *

from glio.datasets.mri_preloaded import *
from glio.specific.mri_around import *
from glio.specific.vkr import *
from glio.transforms.intensity import RandScale, RandShift
from glio.transforms.spatial import RandFlipt

from glio.torch_tools import ConcatZeroChannelsToDataloader, BatchInputTransforms
# Out:
# d:\miniconda3\envs\pytorch311\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# # Dataset

# %%
rhuhtrain = get_ds_around(RHUH_NOHIST140_NOADC_TRAIN) + get_ds_around(RHUH_NOHIST140_NOADC_TEST)
bratstest = get_ds_around(BRATS2024SMALL_NOHIST96_TEST)

# %%
from monai import transforms as mtf

# fast tfms
gaussianblur = mtf.RandGaussianSmooth(prob=0.1) # type:ignore
contrast = mtf.RandAdjustContrast(gamma = (0.5, 2), prob=0.1) # type:ignore

# slower tfms
biasfield = mtf.RandBiasField(prob=0.1) # type:ignore
hist_shift = mtf.RandHistogramShift(prob=0.05) # type:ignore
gibbs = mtf.RandGibbsNoise(prob=0.1) # type:ignore
riccan = mtf.RandRicianNoise(std=0.5, prob=0.05) # type:ignore

# very slow
kspike = mtf.RandKSpaceSpikeNoise(prob=0.1) # type:ignore

def rand_shuffle_channels_around(x:torch.Tensor, channels_per = 3):
    if random.random() < 0.1:
        num_groups = int(x.shape[0] / channels_per)
        perm = torch.randperm(num_groups, dtype=torch.int32)
        img= x.reshape(num_groups, channels_per, *x.shape[1:])[perm].flatten(0, 1)
        return img
    return x

def rand_group_dropout(x):
    if random.random() < 0.05: return torch.zeros_like(x)
    if random.random() < 0.05: return torch.randn_like(x)
    return x

def randnoise(x):
    if random.random() < 0.1: return x + torch.randn_like(x) * random.triangular(0, 0.5, 0)
    return x

# %%
dstrain = DSToTarget(0)
dstest = DSToTarget(0)

dstrain.add_samples(rhuhtrain, loader_around_seq, [randcrop, RandFlipt(p=0.5)], [get0, rand_shuffle_channels_around, GroupwiseTfms((randnoise, RandScale(p=0.3), RandShift(p=0.3), rand_group_dropout))], get1)
dstest.add_samples(bratstest, loader_around_seq, randcrop, get0, get1)
print(len(dstrain))
print(len(dstest))
# Out:
# 20893
# 3437

# %% [markdown]
# # Performance

# %%
x = torch.randn((3,96,96))
with perf_counter_context():
    for i in range(100):
        dstrain[i]
# Out:
# Context took 0.5398770999890985 perf_counter seconds

# %% [markdown]
# # Inputs / targets preview

# %%
fig = Figure()
sample_ = dstrain[300]
fig.add().imshow_batch(sample_[0]).style_img('inputs')
fig.add().imshow_batch(sample_[1]).style_img('targets')
sample_ = dstest[20]
fig.add().imshow_batch(sample_[0]).style_img('inputs - test')
fig.add().imshow_batch(sample_[1]).style_img('targets - test')
fig.create(2, figsize=(24,24))
# Out:
# (<Figure size 2400x2400 with 4 Axes>,
#  array([[<Axes: title={'center': 'inputs'}>,
#          <Axes: title={'center': 'targets'}>],
#         [<Axes: title={'center': 'inputs - test'}>,
#          <Axes: title={'center': 'targets - test'}>]], dtype=object))

# %% [markdown]
# # Model

# %%
from monai.networks.nets import HighResNet # type:ignore
def HighResNet_noReLUattheend(in_channels=12, out_channels=20):
    model = HighResNet(2, in_channels, out_channels)
    model.blocks[-1].adn = nn.Identity()
    return model

single_tfms = Compose(rand_shuffle_channels_around, GroupwiseTfms((randnoise, RandScale(p=0.3, val=(0.75, 1.5)), RandShift(p=0.3, val=(-0.3, 0.3)), rand_group_dropout)))
batch_tfms = torch.vmap(single_tfms, randomness='different')

mse = torch.nn.MSELoss()

class ContextHRN(nn.Module):
    def __init__(self):
        super().__init__()
        self.batch_tfms = nn.Identity()
        self.hrn = HighResNet_noReLUattheend(12, 20)

    def forward(self, x:torch.Tensor):
        self.tfmed = self.batch_tfms(x)
        self.processed = self.hrn(self.tfmed)
        #loss = mse(self.processed[:, :12], x)
        return self.processed


contextnet = ContextHRN()
contextnet.load_state_dict(torch.load(r"F:\Stuff\Programming\experiments\vkr\training\RHUH full + BRATS-small test as test, 32\checkpoints\int+flip, contextnet+adan+dicefocal lr1e-01 OneCycleLR\2. 29.05.2024 11-00-54 (6-4571; testloss=0.69167; testacc=0.95965)\model.pt"))
# Out:
# <All keys matched successfully>

# %%
from monai.networks.nets import SegResNetDS # type:ignore
class ContextSegResNetDS(nn.Module):
    def __init__(self):
        super().__init__()
        self.context_block = ContextHRN()
        self.context_block.load_state_dict(torch.load(r"F:\Stuff\Programming\experiments\vkr\training\RHUH full + BRATS-small test as test, 32\checkpoints\int+flip, contextnet+adan+dicefocal lr1e-01 OneCycleLR\2. 29.05.2024 11-00-54 (6-4571; testloss=0.69167; testacc=0.95965)\model.pt"))
        self.net = SegResNetDS(2, 32, 32, 4)
    def forward(self, x:torch.Tensor):
        self.context = self.context_block(x)
        return self.net(torch.cat((x, self.context), 1))
print(f"{count_parameters(ContextSegResNetDS()) = }")

summary(ContextSegResNetDS(), (4, 12, 96, 96))
# Out:
# count_parameters(ContextSegResNetDS()) = 6928676
# path                                         module                                       input size               output size              params    buffers
# __main__.ContextSegResNetDS/context_block/batch_tfmstorch.nn.modules.linear.Identity             (4, 12, 96, 96)          (4, 12, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/0/convtorch.nn.modules.conv.Conv2d                 (4, 12, 96, 96)          (4, 16, 96, 96)          1728      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/0/adn/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/0/adn/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/0/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/2/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/1/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/0/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/2/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/2/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/0/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/2/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 16, 96, 96)          2304      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/3/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 16, 96, 96)          (4, 16, 96, 96)          32        33
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/0/Atorch.nn.modules.activation.ReLU             (4, 16, 96, 96)          (4, 16, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 16, 96, 96)          (4, 32, 96, 96)          4608      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/2/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/4/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 16, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/0/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/2/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/5/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/0/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/2/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/6/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/0/Atorch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 64, 96, 96)          18432     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/2/Atorch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/7/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 32, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/0/Atorch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/2/Atorch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/8/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/0/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/0/Atorch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/1/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/2/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 96, 96)          (4, 64, 96, 96)          128       129
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/2/Atorch.nn.modules.activation.ReLU             (4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/layers/3/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 64, 96, 96)          36864     0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/9/chn_padmonai.networks.layers.simplelayers.ChannelPad(4, 64, 96, 96)          (4, 64, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/10/convtorch.nn.modules.conv.Conv2d                 (4, 64, 96, 96)          (4, 80, 96, 96)          5120      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/10/adn/Ntorch.nn.modules.batchnorm.BatchNorm2d       (4, 80, 96, 96)          (4, 80, 96, 96)          160       161
# __main__.ContextSegResNetDS/context_block/hrn/blocks/10/adn/Atorch.nn.modules.activation.ReLU             (4, 80, 96, 96)          (4, 80, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/10/adn/Dtorch.nn.modules.dropout.Dropout             (4, 80, 96, 96)          (4, 80, 96, 96)          0         0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/11/convtorch.nn.modules.conv.Conv2d                 (4, 80, 96, 96)          (4, 20, 96, 96)          1600      0
# __main__.ContextSegResNetDS/context_block/hrn/blocks/11/adntorch.nn.modules.linear.Identity             (4, 20, 96, 96)          (4, 20, 96, 96)          0         0
# __main__.ContextSegResNetDS/net/encoder/conv_inittorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/0/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/net/encoder/layers/0/downsampletorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 64, 48, 48)          18432     0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/act1torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/conv1torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/act2torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/encoder/layers/1/blocks/1/conv2torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/encoder/layers/1/downsampletorch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 128, 24, 24)         73728     0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/act1torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/conv1torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/act2torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/2/blocks/1/conv2torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/encoder/layers/2/downsampletorch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 256, 12, 12)         294912    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/act1torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/conv1torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/act2torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/1/conv2torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/act1torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/conv1torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/act2torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/2/conv2torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/act1torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/conv1torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 256, 12, 12)         (4, 256, 12, 12)         512       513
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/act2torch.nn.modules.activation.ReLU             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/encoder/layers/3/blocks/3/conv2torch.nn.modules.conv.Conv2d                 (4, 256, 12, 12)         (4, 256, 12, 12)         589824    0
# __main__.ContextSegResNetDS/net/encoder/layers/3/downsampletorch.nn.modules.linear.Identity             (4, 256, 12, 12)         (4, 256, 12, 12)         0         0
# __main__.ContextSegResNetDS/net/up_layers/0/upsample/deconvtorch.nn.modules.conv.ConvTranspose2d        (4, 256, 12, 12)         (4, 128, 24, 24)         294912    0
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 128, 24, 24)         (4, 128, 24, 24)         256       257
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 128, 24, 24)         (4, 128, 24, 24)         0         0
# __main__.ContextSegResNetDS/net/up_layers/0/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 128, 24, 24)         (4, 128, 24, 24)         147456    0
# __main__.ContextSegResNetDS/net/up_layers/1/upsample/deconvtorch.nn.modules.conv.ConvTranspose2d        (4, 128, 24, 24)         (4, 64, 48, 48)          73728     0
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 64, 48, 48)          (4, 64, 48, 48)          128       129
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 64, 48, 48)          (4, 64, 48, 48)          0         0
# __main__.ContextSegResNetDS/net/up_layers/1/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 64, 48, 48)          (4, 64, 48, 48)          36864     0
# __main__.ContextSegResNetDS/net/up_layers/2/upsample/deconvtorch.nn.modules.conv.ConvTranspose2d        (4, 64, 48, 48)          (4, 32, 96, 96)          18432     0
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/norm1torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/act1torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/conv1torch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/norm2torch.nn.modules.batchnorm.BatchNorm2d       (4, 32, 96, 96)          (4, 32, 96, 96)          64        65
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/act2torch.nn.modules.activation.ReLU             (4, 32, 96, 96)          (4, 32, 96, 96)          0         0
# __main__.ContextSegResNetDS/net/up_layers/2/blocks/0/conv2torch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 32, 96, 96)          9216      0
# __main__.ContextSegResNetDS/net/up_layers/2/headtorch.nn.modules.conv.Conv2d                 (4, 32, 96, 96)          (4, 4, 96, 96)           132       0

# %% [markdown]
# # Train

# %%
from stuff.found.torch.optim.Adan import Adan
from monai.losses import DiceFocalLoss # type:ignore

MODEL = ContextSegResNetDS()
NAME = f"{MODEL.__class__.__name__}"
LR = 2e-3
BATCH_SIZE = 32
N_EPOCHS = 20

# dl_train = DataLoader(ds_train, BATCH_SIZE)
dltrain = DataLoader(dstrain, BATCH_SIZE, shuffle=True)
dltest = DataLoader(dstest, BATCH_SIZE)

OPT = Adan(MODEL.parameters(), lr=LR)
LOSS_FN = DiceFocalLoss(softmax=True)
SCHED = lr_scheduler.OneCycleLR(OPT, max_lr=LR, steps_per_epoch=len(dltrain), epochs=N_EPOCHS)

clean_mem()
# MODEL = gnn.LSUV(MODEL, dltrain, max_iter=10)

CALLBACKS =  (Metric_Loss(),
              Log_Time(), Save_Best(), Save_Last(), Log_LR(), PerformanceTweaks(True), Accelerate("no"),
              MONAI_IoU(4, True, True, step=32, name='iou'),
              Torcheval_AURPC(4, True, step=32),
              Torcheval_AUROC(4, True, step=32),
              MONAI_ConfusionMatrix(step=4), MONAI_ConfusionMatrixMetrics(),
              MONAI_ConfusionMatrix(step=4, include_bg = False, name="nobg confusion matrix"), MONAI_ConfusionMatrixMetrics(key = 'nobg confusion matrix', prefix='nobg '),
              FastProgressBar(step_batch=128, plot=True, metrics=('train loss', 'test loss', 
                                                                  'test balanced accuracy', 'test nobg balanced accuracy',
                                                                  'test f1 score', 'test nobg f1 score'), maxv=1),
              Summary(),
              PlotSummary(path='summaries'),
              PrintLoss(),
              SaveReferenceVisualizationsAfterEachEpoch('reference preds'),
              #Metric_PredsTargetsFn(LOSS_FN, name='dice loss'),
              #CallTrainAndEvalOnOptimizer(),
              #AddLossReturnedByModelToLossInBackward(),
            )

LEARNER_NAME = f"{TITLE} lr{LR:.0e} OneCycleLR"
learner = Learner(MODEL, LEARNER_NAME,
                  cbs = CALLBACKS,
                  loss_fn=LOSS_FN,
                  optimizer=OPT,
                  scheduler=SCHED,)
learner.fit(N_EPOCHS, dltrain, dltest, test_first=False, test_on_interrupt=False)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# train loss = 0.6009
# time: min: 8.1587; max: 13012.1769; last: 13012.1769
# lr: min: 0.0000; max: 0.0020; last: 0.0000
# train loss: min: 0.2218; max: 1.6154; last: 0.2713
# train iou: min: 0.0030; max: 0.9724; last: 0.9555
# train average precision: min: 0.2451; max: 0.4171; last: 0.3106
# train roc auc: min: 0.3939; max: 0.7792; last: 0.6321
# test loss: min: 0.3264; max: 0.4918; last: 0.3264
# test iou: min: 0.8912; max: 0.9847; last: 0.9227
# test average precision: min: 0.2472; max: 0.3163; last: 0.2589
# test roc auc: min: 0.4684; max: 0.6607; last: 0.5118
# test sensitivity: min: 0.7343; max: 0.7819; last: 0.7819
# test specificity: min: 0.9570; max: 0.9663; last: 0.9663
# test precision: min: 0.8831; max: 0.8932; last: 0.8932
# test negative predictive value: min: 0.9766; max: 0.9805; last: 0.9805
# test miss rate: min: 0.2181; max: 0.2657; last: 0.2181
# test fall out: min: 0.0337; max: 0.0430; last: 0.0337
# test false discovery rate: min: 0.1068; max: 0.1169; last: 0.1068
# test false omission rate: min: 0.0195; max: 0.0234; last: 0.0195
# test prevalence threshold: min: 0.1158; max: 0.1250; last: 0.1158
# test threat score: min: 0.6677; max: 0.7174; last: 0.7174
# test accuracy: min: 0.9833; max: 0.9860; last: 0.9860
# test balanced accuracy: min: 0.8473; max: 0.8741; last: 0.8741
# test f1 score: min: 0.7831; max: 0.8250; last: 0.8250
# test matthews correlation coefficient: min: 0.7643; max: 0.8047; last: 0.8047
# test fowlkes mallows index: min: 0.7956; max: 0.8312; last: 0.8312
# test informedness: min: 0.6945; max: 0.7481; last: 0.7481
# test markedness: min: 0.8598; max: 0.8736; last: 0.8736
# test nobg sensitivity: min: 0.6480; max: 0.7111; last: 0.7111
# test nobg specificity: min: 0.9931; max: 0.9944; last: 0.9944
# test nobg precision: min: 0.8493; max: 0.8619; last: 0.8619
# test nobg negative predictive value: min: 0.9905; max: 0.9921; last: 0.9921
# test nobg miss rate: min: 0.2889; max: 0.3520; last: 0.2889
# test nobg fall out: min: 0.0056; max: 0.0069; last: 0.0056
# test nobg false discovery rate: min: 0.1381; max: 0.1507; last: 0.1381
# test nobg false omission rate: min: 0.0079; max: 0.0095; last: 0.0079
# test nobg prevalence threshold: min: 0.0690; max: 0.0730; last: 0.0690
# test nobg threat score: min: 0.5642; max: 0.6294; last: 0.6294
# test nobg accuracy: min: 0.9844; max: 0.9871; last: 0.9871
# test nobg balanced accuracy: min: 0.8206; max: 0.8527; last: 0.8527
# test nobg f1 score: min: 0.7145; max: 0.7699; last: 0.7699
# test nobg matthews correlation coefficient: min: 0.7236; max: 0.7717; last: 0.7717
# test nobg fowlkes mallows index: min: 0.7311; max: 0.7781; last: 0.7781
# test nobg informedness: min: 0.6412; max: 0.7054; last: 0.7054
# test nobg markedness: min: 0.8398; max: 0.8541; last: 0.8541

# %%
qimshow_batch(learner.model.context[14], scale_each=True, maxelems=100)

# %%
LR = 5e-4
OPT = Adan(learner.model.parameters(), lr=LR)
SCHED = lr_scheduler.OneCycleLR(OPT, max_lr=LR, steps_per_epoch=len(dltrain), epochs=N_EPOCHS)
learner.fit(N_EPOCHS, dltrain, dltest, test_first=False, test_on_interrupt=False, extra=(Set_Optimizer(OPT), Set_Scheduler(SCHED)))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# time: min: 8.1587; max: 27870.9439; last: 27870.9439
# lr: min: 0.0000; max: 0.0020; last: 0.0000
# train loss: min: 0.2145; max: 1.6154; last: 0.2497
# train iou: min: 0.0030; max: 0.9769; last: 0.9619
# train average precision: min: 0.2451; max: 0.4343; last: 0.3058
# train roc auc: min: 0.3598; max: 0.7920; last: 0.6991
# test loss: min: 0.3241; max: 0.4918; last: 0.3351
# test iou: min: 0.8868; max: 0.9847; last: 0.9744
# test average precision: min: 0.2472; max: 0.3341; last: 0.2766
# test roc auc: min: 0.4225; max: 0.7200; last: 0.5522
# test sensitivity: min: 0.7343; max: 0.7917; last: 0.7804
# test specificity: min: 0.9570; max: 0.9695; last: 0.9639
# test precision: min: 0.8831; max: 0.8978; last: 0.8978
# test negative predictive value: min: 0.9766; max: 0.9820; last: 0.9820
# test miss rate: min: 0.2083; max: 0.2657; last: 0.2196
# test fall out: min: 0.0305; max: 0.0430; last: 0.0361
# test false discovery rate: min: 0.1022; max: 0.1169; last: 0.1022
# test false omission rate: min: 0.0180; max: 0.0234; last: 0.0180
# test prevalence threshold: min: 0.1133; max: 0.1250; last: 0.1165
# test threat score: min: 0.6677; max: 0.7272; last: 0.7199
# test accuracy: min: 0.9833; max: 0.9867; last: 0.9863
# test balanced accuracy: min: 0.8473; max: 0.8801; last: 0.8721
# test f1 score: min: 0.7831; max: 0.8328; last: 0.8268
# test matthews correlation coefficient: min: 0.7643; max: 0.8132; last: 0.8059
# test fowlkes mallows index: min: 0.7956; max: 0.8381; last: 0.8329
# test informedness: min: 0.6945; max: 0.7603; last: 0.7443
# test markedness: min: 0.8598; max: 0.8798; last: 0.8798
# test nobg sensitivity: min: 0.6480; max: 0.7241; last: 0.7088
# test nobg specificity: min: 0.9931; max: 0.9950; last: 0.9950
# test nobg precision: min: 0.8493; max: 0.8685; last: 0.8685
# test nobg negative predictive value: min: 0.9905; max: 0.9925; last: 0.9921
# test nobg miss rate: min: 0.2759; max: 0.3520; last: 0.2912
# test nobg fall out: min: 0.0050; max: 0.0069; last: 0.0050
# test nobg false discovery rate: min: 0.1315; max: 0.1507; last: 0.1315
# test nobg false omission rate: min: 0.0075; max: 0.0095; last: 0.0079
# test nobg prevalence threshold: min: 0.0670; max: 0.0730; last: 0.0670
# test nobg threat score: min: 0.5642; max: 0.6421; last: 0.6329
# test nobg accuracy: min: 0.9844; max: 0.9876; last: 0.9876
# test nobg balanced accuracy: min: 0.8206; max: 0.8593; last: 0.8519
# test nobg f1 score: min: 0.7145; max: 0.7800; last: 0.7723
# test nobg matthews correlation coefficient: min: 0.7236; max: 0.7809; last: 0.7742
# test nobg fowlkes mallows index: min: 0.7311; max: 0.7870; last: 0.7804
# test nobg informedness: min: 0.6412; max: 0.7186; last: 0.7038
# test nobg markedness: min: 0.8398; max: 0.8606; last: 0.8606

# %%
qimshow_batch(learner.model.context[14], scale_each=True, maxelems=100)

# %%
inputs, targets = dstrain[1616]
inputs = inputs.unsqueeze(0)
f = Figure()
preds = learner.inference(inputs)
f.add().imshow_batch(inputs[0], maxelems=100, scale_each=True).style_img()
f.add().imshow_batch(learner.model.context[0], maxelems=100, scale_each=True).style_img()
f.add().imshow_batch(preds[0], maxelems=100, scale_each=True).style_img()
f.add().imshow(preds[0].argmax(0), vmin=0, vmax=3).style_img()
f.add().imshow(targets.argmax(0), vmin=0, vmax=3).style_img()
f.show(figsize=(17,17), nrow=2)
