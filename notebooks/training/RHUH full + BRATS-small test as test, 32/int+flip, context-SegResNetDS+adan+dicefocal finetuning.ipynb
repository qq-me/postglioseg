# %% [markdown]
# # Перемешиваем модальности

# %% [markdown]
# # Metadata
# transforms, model+optimizer+loss, hyperparams

# %%
TITLE = "int+flip, SegResNetDS+adan+dicefocal"

# %% [markdown]
# # Imports

# %%
from glio.imports import *
from glio.importsglio import *

from glio.datasets.mri_preloaded import *
from glio.specific.mri_around import *
from glio.specific.vkr import *
from glio.transforms.intensity import RandScale, RandShift
from glio.transforms.spatial import RandFlipt

from glio.torch_tools import ConcatZeroChannelsToDataloader, BatchInputTransforms
# Out:
# d:\miniconda3\envs\pytorch311\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# # Dataset

# %%
rhuhtrain = get_ds_around(RHUH_NOHIST140_NOADC_TRAIN) + get_ds_around(RHUH_NOHIST140_NOADC_TEST)
bratstest = get_ds_around(BRATS2024SMALL_NOHIST96_TEST)

# %%
from monai import transforms as mtf

# fast tfms
gaussianblur = mtf.RandGaussianSmooth(prob=0.1) # type:ignore
contrast = mtf.RandAdjustContrast(gamma = (0.5, 2), prob=0.1) # type:ignore

# slower tfms
biasfield = mtf.RandBiasField(prob=0.1) # type:ignore
hist_shift = mtf.RandHistogramShift(prob=0.05) # type:ignore
gibbs = mtf.RandGibbsNoise(prob=0.1) # type:ignore
riccan = mtf.RandRicianNoise(std=0.5, prob=0.05) # type:ignore

# very slow
kspike = mtf.RandKSpaceSpikeNoise(prob=0.1) # type:ignore

def rand_shuffle_channels_around(x:torch.Tensor, channels_per = 3):
    if random.random() < 0.1:
        num_groups = int(x.shape[0] / channels_per)
        perm = torch.randperm(num_groups, dtype=torch.int32)
        img= x.reshape(num_groups, channels_per, *x.shape[1:])[perm].flatten(0, 1)
        return img
    return x

def rand_group_dropout(x):
    if random.random() < 0.05: return torch.zeros_like(x)
    if random.random() < 0.05: return torch.randn_like(x)
    return x

def randnoise(x):
    if random.random() < 0.1: return x + torch.randn_like(x) * random.triangular(0, 0.5, 0)
    return x

# %%
dstrain = DSToTarget(0)
dstest = DSToTarget(0)

dstrain.add_samples(rhuhtrain, loader_around_seq, [randcrop, RandFlipt(p=0.5)], [get0, rand_shuffle_channels_around, GroupwiseTfms((randnoise, RandScale(p=0.3), RandShift(p=0.3), rand_group_dropout))], get1)
dstest.add_samples(bratstest, loader_around_seq, randcrop, get0, get1)
print(len(dstrain))
print(len(dstest))

# %% [markdown]
# # Performance

# %%
x = torch.randn((3,96,96))
with perf_counter_context():
    for i in range(100):
        dstrain[i]
# Out:
# Context took 0.5156871000071988 perf_counter seconds

# %% [markdown]
# # Inputs / targets preview

# %%
fig = Figure()
sample_ = dstrain[300]
fig.add().imshow_batch(sample_[0]).style_img('inputs')
fig.add().imshow_batch(sample_[1]).style_img('targets')
sample_ = dstest[20]
fig.add().imshow_batch(sample_[0]).style_img('inputs - test')
fig.add().imshow_batch(sample_[1]).style_img('targets - test')
fig.create(2, figsize=(24,24))
# Out:
# (<Figure size 2400x2400 with 4 Axes>,
#  array([[<Axes: title={'center': 'inputs'}>,
#          <Axes: title={'center': 'targets'}>],
#         [<Axes: title={'center': 'inputs - test'}>,
#          <Axes: title={'center': 'targets - test'}>]], dtype=object))

# %% [markdown]
# # Model

# %%
from monai.networks.nets import SegResNetDS # type:ignore
print(f"{count_parameters(SegResNetDS(2, 32, 12, 4)) = }")
# Out:
# count_parameters(SegResNetDS(2, 32, 12, 4)) = 6645764

# %% [markdown]
# # Train

# %%
from stuff.found.torch.optim.Adan import Adan
from monai.losses import DiceFocalLoss # type:ignore

MODEL = SegResNetDS(2, 32, 12, 4)
NAME = f"{MODEL.__class__.__name__}"
LR = 2e-3
BATCH_SIZE = 32
N_EPOCHS = 150

# dl_train = DataLoader(ds_train, BATCH_SIZE)
dltrain = DataLoader(dstrain, BATCH_SIZE, shuffle=True)
dltest = DataLoader(dstest, BATCH_SIZE)

OPT = Adan(MODEL.parameters(), lr=LR)
LOSS_FN = DiceFocalLoss(softmax=True)
SCHED = lr_scheduler.OneCycleLR(OPT, max_lr=LR, steps_per_epoch=len(dltrain), epochs=N_EPOCHS)

clean_mem()
# MODEL = gnn.LSUV(MODEL, dltrain, max_iter=10)

CALLBACKS =  (Metric_Loss(),
              Log_Time(), Save_Best(), Save_Last(), Log_LR(), PerformanceTweaks(True), Accelerate("no"),
              MONAI_IoU(4, True, True, step=32, name='iou'),
              Torcheval_AURPC(4, True, step=32),
              Torcheval_AUROC(4, True, step=32),
              MONAI_ConfusionMatrix(step=4), MONAI_ConfusionMatrixMetrics(),
              MONAI_ConfusionMatrix(step=4, include_bg = False, name="nobg confusion matrix"), MONAI_ConfusionMatrixMetrics(key = 'nobg confusion matrix', prefix='nobg '),
              FastProgressBar(step_batch=128, plot=True, metrics=('train loss', 'test loss', 
                                                                  'test balanced accuracy', 'test nobg balanced accuracy',
                                                                  'test f1 score', 'test nobg f1 score'), maxv=1),
              Summary(),
              PlotSummary(path='summaries'),
              PrintLoss(),
              SaveReferenceVisualizationsAfterEachEpoch('reference preds'),
              #Metric_PredsTargetsFn(LOSS_FN, name='dice loss'),
              #CallTrainAndEvalOnOptimizer(),
              #AddLossReturnedByModelToLossInBackward(),
            )

LEARNER_NAME = f"{TITLE} lr{LR:.0e} OneCycleLR"
learner = Learner(MODEL, LEARNER_NAME,
                  cbs = CALLBACKS,
                  loss_fn=LOSS_FN,
                  optimizer=OPT,
                  scheduler=SCHED,)
learner.fit(N_EPOCHS, dltrain, dltest, test_first=True, test_on_interrupt=False)
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# test loss = 1.0272
# test loss: min: 0.2459; max: 1.0949; last: 0.2616                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# test iou: min: 0.1095; max: 0.9825; last: 0.9160
# test average precision: min: 0.2485; max: 0.3556; last: 0.2750
# test roc auc: min: 0.4648; max: 0.6876; last: 0.5858
# test sensitivity: min: 0.3056; max: 0.8085; last: 0.7965
# test specificity: min: 0.7979; max: 0.9700; last: 0.9645
# test precision: min: 0.2596; max: 0.9021; last: 0.9021
# test negative predictive value: min: 0.7592; max: 0.9818; last: 0.9818
# test miss rate: min: 0.1915; max: 0.6944; last: 0.2035
# test fall out: min: 0.0300; max: 0.2021; last: 0.0355
# test false discovery rate: min: 0.0979; max: 0.7404; last: 0.0979
# test false omission rate: min: 0.0182; max: 0.2408; last: 0.0182
# test prevalence threshold: min: 0.1133; max: 0.4874; last: 0.1148
# test threat score: min: 0.0599; max: 0.7444; last: 0.7377
# test accuracy: min: 0.6031; max: 0.9871; last: 0.9870
# test balanced accuracy: min: 0.5517; max: 0.8880; last: 0.8805
# test f1 score: min: 0.1011; max: 0.8449; last: 0.8394
# test matthews correlation coefficient: min: 0.0443; max: 0.8226; last: 0.8174
# test fowlkes mallows index: min: 0.1547; max: 0.8486; last: 0.8443
# test informedness: min: 0.1034; max: 0.7760; last: 0.7609
# test markedness: min: 0.0188; max: 0.8839; last: 0.8839
# test nobg sensitivity: min: 0.3369; max: 0.7466; last: 0.7304
# test nobg specificity: min: 0.7306; max: 0.9955; last: 0.9955
# test nobg precision: min: 0.0128; max: 0.8742; last: 0.8742
# test nobg negative predictive value: min: 0.9708; max: 0.9930; last: 0.9927
# test nobg miss rate: min: 0.2534; max: 0.6631; last: 0.2696
# test nobg fall out: min: 0.0045; max: 0.2694; last: 0.0045
# test nobg false discovery rate: min: 0.1258; max: 0.9872; last: 0.1258
# test nobg false omission rate: min: 0.0070; max: 0.0292; last: 0.0073
# test nobg prevalence threshold: min: 0.0649; max: 0.6409; last: 0.0649
# test nobg threat score: min: 0.0093; max: 0.6655; last: 0.6567
# test nobg accuracy: min: 0.7072; max: 0.9886; last: 0.9886
# test nobg balanced accuracy: min: 0.5337; max: 0.8708; last: 0.8629
# test nobg f1 score: min: 0.0184; max: 0.7964; last: 0.7892
# test nobg matthews correlation coefficient: min: 0.0050; max: 0.7955; last: 0.7900
# test nobg fowlkes mallows index: min: 0.0530; max: 0.8013; last: 0.7957
# test nobg informedness: min: 0.0675; max: 0.7417; last: 0.7259
# test nobg markedness: min: -0.0163; max: 0.8670; last: 0.8670
# time: min: 39.0635; max: 43056.7981; last: 43056.7981
# lr: min: 0.0000; max: 0.0020; last: 0.0000
# train loss: min: 0.0706; max: 1.1362; last: 0.1161
# train iou: min: 0.8783; max: 0.9807; last: 0.9688
# train average precision: min: 0.2456; max: 0.4631; last: 0.2761
# train roc auc: min: 0.3831; max: 0.8307; last: 0.6897

# %% [markdown]
# # Дообучение с brats2024, на generalized dice focal loss

# %%
# del dstrain
# del dstest
# del bratstest
# del rhuhtrain
# del dltest
# del dltrain
train = get_ds_around(RHUH_NOHIST140_NOADC_TRAIN) + get_ds_around(RHUH_NOHIST140_NOADC_TEST) + get_ds_around(BRATS2024SMALL_NOHIST96_TEST)
test = get_ds_around(BRATS2024SMALL_NOHIST96_TRAIN)

# %%
dstrain = DSToTarget(0)
dstest = DSToTarget(0)
dstrain.add_samples(train, loader_around_seq, [randcrop, RandFlipt(p=0.5)], [get0, rand_shuffle_channels_around, GroupwiseTfms((randnoise, RandScale(p=0.3), RandShift(p=0.3), rand_group_dropout))], get1)
dstest.add_samples(test, loader_around_seq, randcrop, get0, get1)
print(len(dstrain))
print(len(dstest))
# Out:
# 24330
# 16376

# %%
x = torch.randn((3,96,96))
with perf_counter_context():
    for i in range(100):
        dstrain[i]
# Out:
# Context took 0.7829358999151736 perf_counter seconds

# %%
fig = Figure()
sample_ = dstrain[300]
fig.add().imshow_batch(sample_[0]).style_img('inputs')
fig.add().imshow_batch(sample_[1]).style_img('targets')
sample_ = dstest[20]
fig.add().imshow_batch(sample_[0]).style_img('inputs - test')
fig.add().imshow_batch(sample_[1]).style_img('targets - test')
fig.create(2, figsize=(24,24))
# Out:
# (<Figure size 2400x2400 with 4 Axes>,
#  array([[<Axes: title={'center': 'inputs'}>,
#          <Axes: title={'center': 'targets'}>],
#         [<Axes: title={'center': 'inputs - test'}>,
#          <Axes: title={'center': 'targets - test'}>]], dtype=object))

# %%
from stuff.found.torch.optim.Adan import Adan
from monai.losses import DiceFocalLoss, GeneralizedDiceFocalLoss # type:ignore

MODEL = SegResNetDS(2, 32, 12, 4)
NAME = f"{MODEL.__class__.__name__}"
LR = 1e-3
BATCH_SIZE = 32
N_EPOCHS = 100

dltrain = DataLoader(dstrain, BATCH_SIZE, shuffle=True)
dltest = DataLoader(dstest, BATCH_SIZE)

path = r'F:\Stuff\Programming\experiments\vkr\training\RHUH full + BRATS-small test as test, 32\checkpoints\int+flip, SegResNetDS+adan+dicefocal lr2e-03\1. 26.05.2024 08-34-05 (118-77707; testloss=0.24589; testacc=0.98631)'
OPT = Adan(MODEL.parameters(), lr=LR, weight_decay=1e-2, eps=1e-6)
LOSS_FN = GeneralizedDiceFocalLoss(softmax=True)
SCHED = lr_scheduler.OneCycleLR(OPT, max_lr=LR, steps_per_epoch=len(dltrain), epochs=N_EPOCHS)
CALLBACKS =  (Metric_Loss(),
              Log_Time(), Save_Best(), Save_Last(), Log_LR(), PerformanceTweaks(True), Accelerate("no"),
              MONAI_IoU(4, True, True, step=32, name='iou'),
              Torcheval_AURPC(4, True, step=32),
              Torcheval_AUROC(4, True, step=32),
              MONAI_ConfusionMatrix(step=4), MONAI_ConfusionMatrixMetrics(),
              MONAI_ConfusionMatrix(step=4, include_bg = False, name="nobg confusion matrix"), MONAI_ConfusionMatrixMetrics(key = 'nobg confusion matrix', prefix='nobg '),
              FastProgressBar(step_batch=128, plot=True, metrics=('train loss', 'test loss', 
                                                                  'test balanced accuracy', 'test nobg balanced accuracy',
                                                                  'test f1 score', 'test nobg f1 score'), maxv=1),
              Summary(),
              PlotSummary(path='summaries'),
              PrintLoss(),
              SaveReferenceVisualizationsAfterEachEpoch('reference preds'),
              #Metric_PredsTargetsFn(LOSS_FN, name='dice loss'),
              #CallTrainAndEvalOnOptimizer(),
              #AddLossReturnedByModelToLossInBackward(),
            )
learner = Learner.from_checkpoint(path, model=MODEL, optimizer=OPT, scheduler=SCHED, cbs=CALLBACKS)
clean_mem()

learner.name = f'int+flip, SegResNetDS+adan+gdicefocal lr{LR:.0e} wd2e-2 eps1e-6 OneCycleLR + brats-small, from pretrained on dicefocal'
learner.optimizer = OPT
learner.loss_fn = LOSS_FN
learner.scheduler = SCHED

dice = LOSS_FN = DiceFocalLoss(softmax=True)
learner.fit(N_EPOCHS, dltrain, dltest, test_first=True, test_on_interrupt=False, extra=Metric_PredsTargetsFn(dice, name='dice loss'))
plt.show()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='56' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.00% [56/100 7:31:08&lt;5:54:28]
#     </div>
#
#
#
#     <div>
#       <progress value='643' class='' max='761' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.49% [643/761 04:43&lt;00:51]
#     </div>
# test loss = 0.1993
# Keyboard interrupt, stopping the training...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# test loss: min: 0.2487; max: 1.0949; last: 0.3433
# test iou: min: 0.1095; max: 0.9825; last: 0.9652
# test average precision: min: 0.2485; max: 0.3556; last: 0.2860
# test roc auc: min: 0.4705; max: 0.6772; last: 0.5840
# test sensitivity: min: 0.3056; max: 0.8416; last: 0.8391
# test specificity: min: 0.7979; max: 0.9700; last: 0.9642
# test precision: min: 0.2596; max: 0.9192; last: 0.9191
# test negative predictive value: min: 0.7592; max: 0.9806; last: 0.9805
# test miss rate: min: 0.1584; max: 0.6944; last: 0.1609
# test fall out: min: 0.0300; max: 0.2021; last: 0.0358
# test false discovery rate: min: 0.0808; max: 0.7404; last: 0.0809
# test false omission rate: min: 0.0194; max: 0.2408; last: 0.0195
# test prevalence threshold: min: 0.1098; max: 0.4874; last: 0.1105
# test threat score: min: 0.0599; max: 0.7874; last: 0.7854
# test accuracy: min: 0.6031; max: 0.9881; last: 0.9879
# test balanced accuracy: min: 0.5517; max: 0.9033; last: 0.9017
# test f1 score: min: 0.1011; max: 0.8761; last: 0.8747
# test matthews correlation coefficient: min: 0.0443; max: 0.8508; last: 0.8492
# test fowlkes mallows index: min: 0.1547; max: 0.8782; last: 0.8769
# test informedness: min: 0.1034; max: 0.8066; last: 0.8033
# test markedness: min: 0.0188; max: 0.8996; last: 0.8996
# test nobg sensitivity: min: 0.3369; max: 0.7908; last: 0.7875
# test nobg specificity: min: 0.7306; max: 0.9962; last: 0.9962
# test nobg precision: min: 0.0128; max: 0.8971; last: 0.8971
# test nobg negative predictive value: min: 0.9708; max: 0.9937; last: 0.9935
# test nobg miss rate: min: 0.2092; max: 0.6631; last: 0.2125
# test nobg fall out: min: 0.0038; max: 0.2694; last: 0.0038
# test nobg false discovery rate: min: 0.1029; max: 0.9872; last: 0.1029
# test nobg false omission rate: min: 0.0063; max: 0.0292; last: 0.0065
# test nobg prevalence threshold: min: 0.0583; max: 0.6409; last: 0.0583
# test nobg threat score: min: 0.0093; max: 0.7233; last: 0.7207
# test nobg accuracy: min: 0.7072; max: 0.9903; last: 0.9901
# test nobg balanced accuracy: min: 0.5337; max: 0.8935; last: 0.8918
# test nobg f1 score: min: 0.0184; max: 0.8382; last: 0.8364
# test nobg matthews correlation coefficient: min: 0.0050; max: 0.8360; last: 0.8343
# test nobg fowlkes mallows index: min: 0.0530; max: 0.8410; last: 0.8393
# test nobg informedness: min: 0.0675; max: 0.7870; last: 0.7837
# test nobg markedness: min: -0.0163; max: 0.8906; last: 0.8906
# time: min: 39.0635; max: 32877.6641; last: 27355.8193
# lr: min: 0.0000; max: 0.0020; last: 0.0000
# train loss: min: 0.0828; max: 1.1362; last: 0.2448
# train iou: min: 0.8783; max: 0.9827; last: 0.9664
# train average precision: min: 0.2456; max: 0.4631; last: 0.2737
# train roc auc: min: 0.3831; max: 0.8307; last: 0.6041
# test dice loss: min: 0.2635; max: 0.4585; last: 0.4483
# train dice loss: min: 0.1129; max: 0.5981; last: 0.4545
