# %%
from distributions import DistributionLabeled

# %%
ds = DistributionLabeled(size=2, labels=["x", "y"], class_col = "label")
ds.add_normal(100, "x", [(0,1),(0,1)])
ds.add_normal(100, "x", [(1,2),(1,2)])
ds.add_normal(100, "y", [(0,1),(1,2)])
ds.add_normal(100, "y", [(1,2),(0,1)])

ds.alt_scatter()
# Out:
# alt.Chart(...)
